# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='C:/Users/chandan/Desktop/model weights/model1/best.pt')
# Out:
# Using cache found in C:\Users\chandan/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-9-11 Python-3.10.9 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
img=r"E:\SIH\train_data\images\test\004250004.jpg"

# %%
result=model(img)

# %%
result.print()
# Out:
# image 1/1: 640x480 1 Flower
# Speed: 105.3ms pre-process, 167.0ms inference, 192.8ms NMS per image at shape (1, 3, 640, 480)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(result.render()))
plt.show()

# %%
result.render()
# Out:
# [array([[[105, 142, 150],
#          [103, 140, 148],
#          [101, 138, 144],
#          ...,
#          [ 15,  40,   1],
#          [ 13,  31,   0],
#          [ 17,  33,   0]],
#
#         [[104, 141, 149],
#          [100, 137, 145],
#          [ 94, 131, 137],
#          ...,
#          [ 17,  42,   2],
#          [ 22,  43,   2],
#          [ 32,  50,  10]],
#
#         [[ 92, 129, 135],
#          [ 92, 129, 135],
#          [ 93, 130, 138],
#          ...,
#          [ 55,  78,  34],
#          [ 44,  67,  21],
#          [ 53,  77,  29]],
#
#         ...,
#
#         [[ 96, 100,  77],
#          [102, 106,  83],
#          [108, 110,  88],
#          ...,
#          [225, 193, 204],
#          [220, 188, 201],
#          [223, 193, 205]],
#
#         [[100, 102,  81],
#          [100,  99,  79],
#          [104, 101,  82],
#          ...,
#          [220, 188, 199],
#          [225, 193, 204],
#          [223, 191, 202]],
#
#         [[123, 122, 104],
#          [120, 119, 101],
#          [119, 113,  97],
#          ...,
#          [219, 187, 198],
#          [217, 184, 195],
#          [225, 192, 203]]], dtype=uint8)]

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
